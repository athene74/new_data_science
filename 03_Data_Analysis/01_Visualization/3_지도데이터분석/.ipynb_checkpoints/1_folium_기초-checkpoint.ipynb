# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.2-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\user\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/108.4 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 108.4/108.4 kB 2.1 MB/s eta 0:00:00
# Downloading branca-0.7.2-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.2 folium-0.17.0

# %%
import folium

# %% [markdown]
# # folium 지도맵 라이브러리 기초

# %% [markdown]
# ## 위/경도란?

# %% [markdown]
# * 위도(latitude)
#     * 지구의 적도를 기준으로 북쪽(North)과 남쪽(South)을 나타냄
#     * 적도는 0도이며, 적도에서 북쪽으로 이동할수록 위도는 증가, 적도에서 남쪽으로 이동할수록 위도는 감소.
#     * 위도의 범위는 -90도에서 +90도까지이며, 적도가 0도, 북극이 +90, 남극이 -90
#     * 위도를 통해 지구의 세로 방향 위치를 파악.
# * 경도(Longitude)
#     * 지구를 동서로 나누는 선인 자오선(meridian)을 기준으로 동쪽(East)과 서쪽(West)을 나타냄
#     * 자오선은 그리니치 천문대(Greenwich Observatory)를 기준으로 설정.
#     * 자오선은 0도이며, 동쪽으로 이동할수록 경도는 증가, 서쪽으로 이동할수록 경도는 감소.
#     * 경도의 범위는 -180도에서 +180도까지, 동경이 양수, 서경이 음수.
#     * 경도를 통해 지구의 가로 방향 위치를 파악.

# %% [markdown]
# # 위/경도 좌표 확인하기

# %% [markdown]
# * 위도, 경도 정보 제공 사이트

# %% [markdown]
# https://www.findlatlng.org/

# %% [raw]
# 원하는 지역, 건물, 상호를 입력하면 위/경도 좌표를 얻을 수 있다.

# %% [markdown]
# ## 기본 좌표 설정

# %% [markdown]
# * location에 위도, 경도 정보를 입력하여 입력한 위,경도 좌표를 기준으로 지도를 그릴 수 있습니다.
# * 이때 zoom_start 정보를 지정하여 확대의 정도를 지정할 수 있습니다.
# 참고: zoom_start의 범위는 최대 18 입니다.

# %%
# 대구광역시청
# 위도(Latitude) : 35.8715411 / 경도(Longitude) : 128.601505
# 위도
latitude = 35.8715411
# 경도
longitude = 128.601505

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=15, # 지도의 Zoom 레벨
               # zoom_start=20, # 지도의 Zoom 레벨, 작을 수록 zoom out, 클수록 zoom in
               # width=750, 
               # height=500
               width=1000, 
               height=600
              )
m
#  사용하는 지도는 OpenStreetMap(OSM) 사용
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9916eb5aa723340d6be77ee8c3e3b74d {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9916eb5aa723340d6be77ee8c3e3b74d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9916eb5aa723340d6be77ee8c3e3b74d = L.map(
#                 &quot;map_9916eb5aa723340d6be77ee8c3e3b74d&quot;,
#                 {
#                     center: [35.8715411, 128.601505],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7dd7d882d05d75313504ef3ad1a7ebf9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7dd7d882d05d75313504ef3ad1a7ebf9.addTo(map_9916eb5aa723340d6be77ee8c3e3b74d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 대구디지털 혁신진흥원 위도 경도 활용

# %%
# 대구디지털혁신진흥원
# 위도(Latitude) : 35.835303 / 경도(Longitude) : 128.6815665
# 위도
latitude = 35.835303
# 경도
longitude = 128.6815665

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, # 지도의 Zoom 레벨
               # zoom_start=20, # 지도의 Zoom 레벨, 작을 수록 zoom out, 클수록 zoom in
               width=750, 
               height=500
               # width=1000, 
               # height=600
              )
m
#  사용하는 지도는 OpenStreetMap(OSM) 사용
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1959e3944926f52b7f1058f56aec5760 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1959e3944926f52b7f1058f56aec5760&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1959e3944926f52b7f1058f56aec5760 = L.map(
#                 &quot;map_1959e3944926f52b7f1058f56aec5760&quot;,
#                 {
#                     center: [35.835303, 128.6815665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d7335d32894b92005327091cff4796c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7d7335d32894b92005327091cff4796c.addTo(map_1959e3944926f52b7f1058f56aec5760);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Maker: 위치를 지도상에 마커로 표시
# tooltip은 마커에 마우스 오버시 보이는 텍스트
# popup은 마커를 마우스 클릭시 보이는 텍스트
folium.Marker([latitude, longitude],
              tooltip="대구디지털혁신진흥원",
              # popup="수성알파시티 sw핵심인재과정 진행중"
              popup="강의 진행중"
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1959e3944926f52b7f1058f56aec5760 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1959e3944926f52b7f1058f56aec5760&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1959e3944926f52b7f1058f56aec5760 = L.map(
#                 &quot;map_1959e3944926f52b7f1058f56aec5760&quot;,
#                 {
#                     center: [35.835303, 128.6815665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d7335d32894b92005327091cff4796c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7d7335d32894b92005327091cff4796c.addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#             tile_layer_7d7335d32894b92005327091cff4796c.addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#             var marker_5dc3476801065a0b1be4eaed7b171612 = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#         var popup_edbb5e031b5854299a72c8e5afc6cab4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df397f582443600a57765e6f31f52229 = $(`&lt;div id=&quot;html_df397f582443600a57765e6f31f52229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강의진행중&lt;/div&gt;`)[0];
#                 popup_edbb5e031b5854299a72c8e5afc6cab4.setContent(html_df397f582443600a57765e6f31f52229);
#
#
#
#         marker_5dc3476801065a0b1be4eaed7b171612.bindPopup(popup_edbb5e031b5854299a72c8e5afc6cab4)
#         ;
#
#
#
#
#             marker_5dc3476801065a0b1be4eaed7b171612.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_7d7335d32894b92005327091cff4796c.addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#             var marker_f6ae082344616d020022668c7a0f7a80 = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#         var popup_e6d5edf1c406cf01e1d050253f3d1b4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe11a3a29aa3142166256e2c4badc68b = $(`&lt;div id=&quot;html_fe11a3a29aa3142166256e2c4badc68b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수성알파시티 sw핵심인재과정 진행중&lt;/div&gt;`)[0];
#                 popup_e6d5edf1c406cf01e1d050253f3d1b4f.setContent(html_fe11a3a29aa3142166256e2c4badc68b);
#
#
#
#         marker_f6ae082344616d020022668c7a0f7a80.bindPopup(popup_e6d5edf1c406cf01e1d050253f3d1b4f)
#         ;
#
#
#
#
#             marker_f6ae082344616d020022668c7a0f7a80.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_7d7335d32894b92005327091cff4796c.addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#             var marker_38ef846c1ba2fcf0797127b5582279df = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_1959e3944926f52b7f1058f56aec5760);
#
#
#         var popup_701f4b28e27a3233789d5105ec3cc041 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8b5997fd4742115b5891e282ac64d63 = $(`&lt;div id=&quot;html_a8b5997fd4742115b5891e282ac64d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강의 진행중&lt;/div&gt;`)[0];
#                 popup_701f4b28e27a3233789d5105ec3cc041.setContent(html_a8b5997fd4742115b5891e282ac64d63);
#
#
#
#         marker_38ef846c1ba2fcf0797127b5582279df.bindPopup(popup_701f4b28e27a3233789d5105ec3cc041)
#         ;
#
#
#
#
#             marker_38ef846c1ba2fcf0797127b5582279df.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 사이즈 및 popup 메세지 커스터마이징

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )

html = """
<div style="white-space: nowrap;">
    <div style="display: inline-block; font-weight: bold;">이현구교수님의</div><br>
    <div style="display: inline-block; margin-left: 10px;">지도데이터 강의 진행중</div>
</div>
"""

iframe = folium.IFrame(html=html, width=200, height=60)
popup = folium.Popup(iframe, max_width=200)

folium.Marker([latitude, longitude],
              tooltip="대구디지털혁신진흥원",
              popup=popup
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_debacdba9cc297257c69418bcd7f7c77 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_debacdba9cc297257c69418bcd7f7c77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_debacdba9cc297257c69418bcd7f7c77 = L.map(
#                 &quot;map_debacdba9cc297257c69418bcd7f7c77&quot;,
#                 {
#                     center: [35.835303, 128.6815665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_877a5247238caaf1e668b3fb1a16bd5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_877a5247238caaf1e668b3fb1a16bd5c.addTo(map_debacdba9cc297257c69418bcd7f7c77);
#
#
#             var marker_6d11a11daf2cf2cd0d532467cfbc6160 = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_debacdba9cc297257c69418bcd7f7c77);
#
#
#         var popup_66f7b32dc38dbbf7f440b87f4fdf8224 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var i_frame_ccc364a818f2bf9f50dba2df880b1d44 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_66f7b32dc38dbbf7f440b87f4fdf8224.setContent(i_frame_ccc364a818f2bf9f50dba2df880b1d44);
#
#
#
#         marker_6d11a11daf2cf2cd0d532467cfbc6160.bindPopup(popup_66f7b32dc38dbbf7f440b87f4fdf8224)
#         ;
#
#
#
#
#             marker_6d11a11daf2cf2cd0d532467cfbc6160.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 아이콘 표시

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )
folium.Marker([latitude, longitude],
              tooltip="대구디지털혁신진흥원",
              popup=popup,
              icon=folium.Icon('red', icon='star'),
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f4d80cc0a27c8147a6baa63799e3fe9 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f4d80cc0a27c8147a6baa63799e3fe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f4d80cc0a27c8147a6baa63799e3fe9 = L.map(
#                 &quot;map_9f4d80cc0a27c8147a6baa63799e3fe9&quot;,
#                 {
#                     center: [35.835303, 128.6815665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8079478e5b5b04621ba552f0c0fb8f14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8079478e5b5b04621ba552f0c0fb8f14.addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
#
#             var marker_518430e3a0e69cb6f8fe13ff3828908e = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
#
#             var icon_925a419eaf0a16d99330a5ad9db8e58e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_518430e3a0e69cb6f8fe13ff3828908e.setIcon(icon_925a419eaf0a16d99330a5ad9db8e58e);
#
#
#         var popup_66f7b32dc38dbbf7f440b87f4fdf8224 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var i_frame_ccc364a818f2bf9f50dba2df880b1d44 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_66f7b32dc38dbbf7f440b87f4fdf8224.setContent(i_frame_ccc364a818f2bf9f50dba2df880b1d44);
#
#
#
#         marker_518430e3a0e69cb6f8fe13ff3828908e.bindPopup(popup_66f7b32dc38dbbf7f440b87f4fdf8224)
#         ;
#
#
#
#
#             marker_518430e3a0e69cb6f8fe13ff3828908e.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 반경표시

# %%
folium.CircleMarker([latitude, longitude],
                    color='tomato',
                    radius = 100, #반경
                    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f4d80cc0a27c8147a6baa63799e3fe9 {
#                     position: relative;
#                     width: 750.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f4d80cc0a27c8147a6baa63799e3fe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f4d80cc0a27c8147a6baa63799e3fe9 = L.map(
#                 &quot;map_9f4d80cc0a27c8147a6baa63799e3fe9&quot;,
#                 {
#                     center: [35.835303, 128.6815665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8079478e5b5b04621ba552f0c0fb8f14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8079478e5b5b04621ba552f0c0fb8f14.addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
#
#             var marker_518430e3a0e69cb6f8fe13ff3828908e = L.marker(
#                 [35.835303, 128.6815665],
#                 {}
#             ).addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
#
#             var icon_925a419eaf0a16d99330a5ad9db8e58e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_518430e3a0e69cb6f8fe13ff3828908e.setIcon(icon_925a419eaf0a16d99330a5ad9db8e58e);
#
#
#         var popup_66f7b32dc38dbbf7f440b87f4fdf8224 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var i_frame_ccc364a818f2bf9f50dba2df880b1d44 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;60&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_66f7b32dc38dbbf7f440b87f4fdf8224.setContent(i_frame_ccc364a818f2bf9f50dba2df880b1d44);
#
#
#
#         marker_518430e3a0e69cb6f8fe13ff3828908e.bindPopup(popup_66f7b32dc38dbbf7f440b87f4fdf8224)
#         ;
#
#
#
#
#             marker_518430e3a0e69cb6f8fe13ff3828908e.bindTooltip(
#                 `&lt;div&gt;
#                      대구디지털혁신진흥원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_8079478e5b5b04621ba552f0c0fb8f14.addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
#
#             var circle_marker_8b187908e7faad190fb2b9b223b32a5e = L.circleMarker(
#                 [35.835303, 128.6815665],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;tomato&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;tomato&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9f4d80cc0a27c8147a6baa63799e3fe9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
