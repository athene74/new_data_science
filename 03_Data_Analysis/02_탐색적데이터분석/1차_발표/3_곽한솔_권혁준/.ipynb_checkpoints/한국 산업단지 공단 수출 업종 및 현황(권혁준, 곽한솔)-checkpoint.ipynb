# %% [markdown]
# ## 주요절차

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium import Marker
from folium.plugins import MarkerCluster
from matplotlib import font_manager,rc
plt.rcParams['axes.unicode_minus']=False

# 한글 폰트
from matplotlib import font_manager,rc
font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 데이터 수집

# %% [markdown]
# * 데이터 소스 명시

# %%
export = pd.read_csv('지역별 경상수지_19111924.csv')
export.head(10)
# Out:
#                  통계표 지역별 경상수지 지역별 경상수지 지역코드    단위   변환       2000       2001  \
# 0  2.5.1.4. 지역별 경상수지     경상수지            총계  백만달러  원자료   10,180.8    2,165.2
# 1  2.5.1.4. 지역별 경상수지     경상수지            미국  백만달러  원자료    9,808.3    8,328.7
# 2  2.5.1.4. 지역별 경상수지     경상수지            중국  백만달러  원자료    1,403.4       -758
# 3  2.5.1.4. 지역별 경상수지     경상수지            일본  백만달러  원자료     -8,489   -7,775.6
# 4  2.5.1.4. 지역별 경상수지     경상수지            EU  백만달러  원자료    8,967.4    5,147.6
# 5  2.5.1.4. 지역별 경상수지     경상수지           동남아  백만달러  원자료   11,463.1      6,162
# 6  2.5.1.4. 지역별 경상수지     경상수지            중동  백만달러  원자료  -17,402.2  -15,374.8
# 7  2.5.1.4. 지역별 경상수지     경상수지           중남미  백만달러  원자료    5,003.6    5,111.2
# 8  2.5.1.4. 지역별 경상수지     경상수지            기타  백만달러  원자료     -573.8    1,324.1
# 9  2.5.1.4. 지역별 경상수지     상품수지            총계  백만달러  원자료   15,392.5    9,406.5
#
#         2002       2003       2004  ...       2014       2015       2016  \
# ...

# %% [markdown]
# ### 1. 초기데이터 확인

# %% [markdown]
# #### 1-1. 데이터딕셔너리(각 열의 의미, 데이터의 의미해석관련 스펙 또는 메뉴얼) 확인
# #### 1-2 데이터 기초정보 확인 (사이즈, 열이름, 데이터형)

# %% [markdown]
# * 기초통계정보 확인

# %% [raw]
# 기초 통계값 확인 ( df.describe() )
# [수치형 데이터]
#
# => 수치데이터로서 의미가 는지 판단?
# => 의미가 있는(예: 키, 몸무게, 가격등) 열에 대해 아래 작업 진행  분석
#  - 확인해야 할 사항    수치상
# mean, min, 1q, 2q(중위값), 3q,게, 가격
#  - 시각화
#   히스토그램, 박스플롯 (바이올린플롯)
#  - 이상치 유무 확인
#  - 이상치가 있다면 보정방식을 선택
#   (예: 삭제, 포함)
# - 기초통계값과, 차트 재확인 (이상
# [보정  데이터]유무 확인)
# - 문자열
#  => unique의 결과값에서 파이차트나 막대차트로 그릴수  - 있는 열이 있는지 확인
#  10개미만은 파이차트,  - 도우넛차트 그리기에 용이
#  10개상위 은 파이차트, 막대차트(Top3,5,10 등을 도출.. 그리고 형 데이터나하위 데이터3,5,10)
#
# * 수치 문자 중에 범위화 할
#  예)수 있는 열이 있는지 확인해 보자
#  가격=> 초고가, 고가,위 작업은  일반, 저가
#  주소 추후 진행할 수 있다.pply 함수를 통해
# ly 함수를 통해

# %%
export.describe()
# Out:
#                       통계표 지역별 경상수지 지역별 경상수지 지역코드    단위   변환   2000     2001  \
# count                 135      135           135   135  135    135      135
# unique                  1       15             9     1    1    132      135
# top     2.5.1.4. 지역별 경상수지     경상수지            총계  백만달러  원자료  -12.8  2,165.2
# freq                  135        9            15   135  135      2        1
#
#          2002  2003      2004  ...      2014       2015   2016  2017  \
# count     135   135       135  ...       135        135    135   135
# unique    130   132       135  ...       135        135    134   133
# top     -19.3  -4.2  29,289.9  ...  83,029.6  105,118.6  -53.5  99.5
# freq        2     2         1  ...         1          1      2     2
#
#             2018      2019    2020      2021  2022      2023
# count        135       135     135       135   135       135
# unique       135       135     134       135   134       135
# ...

# %% [markdown]
# ### 2. 데이터 정제

# %% [markdown]
# #### 2.1. 원본데이터에서 분석가능한 형태로 데이터 전처리 (형변환, 열이름 변경등)

# %%
export.columns
# Out:
# Index(['통계표', '지역별 경상수지', '지역별 경상수지 지역코드', '단위', '변환', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %%
export = export.rename(columns = {'지역별 경상수지' : 'balance_item',
                                  '지역별 경상수지 지역코드' : 'nation_code',
                                  '2000' : '00',
                                  '2001' : '01',
                                  '2002' : '02',
                                  '2003' : '03',
                                  '2004' : '04',
                                  '2005' : '05',
                                  '2006' : '06',
                                  '2007' : '07',
                                  '2008' : '08',
                                  '2009' : '09',
                                  '2010' : '10',
                                  '2011' : '11',
                                  '2012' : '12',
                                  '2013' : '13',
                                  '2014' : '14',
                                  '2015' : '15',
                                  '2016' : '16',
                                  '2017' : '17',
                                  '2018' : '18',
                                  '2019' : '19',
                                  '2020' : '20',
                                  '2021' : '21',
                                  '2022' : '22',
                                  '2023' : '23'
})

# %% [markdown]
# #### 2.2. 데이터 클리닝: 이상치, 결측치처리

# %%
# 통계표 : 전부 동일하여 삭제
# 변환 : 전부 동일한 원자료이므로 삭제
# 단위는 : 백만달러로 전부 동일하여 삭제

# %%
export = export.drop(['통계표','변환','단위'], axis=1)
export.head()
# Out:
#   balance_item nation_code        00        01         02         03  \
# 0         경상수지          총계  10,180.8   2,165.2    4,066.1   11,308.3
# 1         경상수지          미국   9,808.3   8,328.7      8,700   10,249.4
# 2         경상수지          중국   1,403.4      -758      1,814    8,782.5
# 3         경상수지          일본    -8,489  -7,775.6  -14,136.6  -18,183.4
# 4         경상수지          EU   8,967.4   5,147.6      1,690    3,762.2
#
#          04         05         06        07  ...         14         15  \
# 0  29,289.9   12,208.6    2,094.8  10,472.5  ...   83,029.6  105,118.6
# 1  19,887.7   11,768.8   10,558.2  14,587.7  ...   41,504.2   33,437.7
# 2  12,620.2   12,573.5    7,604.4   5,087.3  ...   55,764.5   46,365.5
# 3   -23,600  -22,484.3  -25,524.2   -28,967  ...    -16,428  -19,319.7
# 4  10,961.9   13,164.7   18,419.5  13,941.7  ...  -13,236.1   -7,477.8
#
#           16         17         18         19         20        21         22  \
# ...

# %% [markdown]
# ### 3. 초기데이터 분석

# %% [markdown]
# #### 3.1 데이터 정제후 데이터딕셔너리 재확인
# #### 3.2 기초통계 정보 확인 (최대값, 최소값, 평균값, 표준편차, 최빈값, 유일값 등)
# #### 3.3 시각화를 통한 데이터이해 심화

# %% [markdown]
# ##### 데이터 변환

# %%
missing_values = export.isnull().any()  
column_missing_values = missing_values[ missing_values == True ]
column_missing_values # 결측치 X
# Out:
# Series([], dtype: bool)

# %%
export.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   balance_item  135 non-null    object
#  1   nation_code   135 non-null    object
#  2   00            135 non-null    object
#  3   01            135 non-null    object
#  4   02            135 non-null    object
#  5   03            135 non-null    object
#  6   04            135 non-null    object
#  7   05            135 non-null    object
#  8   06            135 non-null    object
#  9   07            135 non-null    object
#  10  08            135 non-null    object
#  11  09            135 non-null    object
#  12  10            135 non-null    object
#  13  11            135 non-null    object
#  14  12            135 non-null    object
#  15  13            135 non-null    object
#  16  14            135 non-null    object
#  17  15            135 non-null    object
# ...

# %%
# 쉼표 제거 함수 정의
def remove_comma(x):
    if isinstance(x, str):
        return x.replace(',', '')
    return x

# %%
# 연도별 데이터 ,제거
years = export.columns[2:] 
export[years] = export[years].applymap(remove_comma)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\197578749.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   export[years] = export[years].applymap(remove_comma)

# %%
#연도별 데이터를 float타입으로 변경
export[years] = export[years].astype(float)

# %%
export.describe()
# Out:
#                  00            01            02            03            04  \
# count    135.000000    135.000000    135.000000    135.000000    135.000000
# mean     301.653333     64.154074    120.477037    335.060741    867.848889
# std     3824.755431   3015.216365   3426.557547   4711.866131   7146.862658
# min   -17402.200000 -15708.800000 -14162.100000 -18274.700000 -23600.000000
# 25%     -113.050000   -282.900000   -256.850000   -221.450000   -252.850000
# 50%       -8.100000    -11.900000    -11.700000    -11.200000     -7.300000
# 75%      171.250000    101.700000    105.100000    153.450000    218.900000
# max    15392.500000  11586.100000  14413.600000  22138.000000  39173.000000
#
#                  05            06            07            08            09  \
# count    135.000000    135.000000    135.000000    135.000000    135.000000
# mean     361.736296     62.068148    310.296296     51.940741    980.373333
# ...

# %%
export['balance_item'].unique()
# Out:
# array(['경상수지', '  상품수지', '    가공서비스수지', '    운송수지', '    여행수지',
#        '    보험서비스수지', '    지식재산권사용료수지', '    통신,컴퓨터,정보서비스수지',
#        '    기타사업서비스수지', '    정부서비스수지', '    기타서비스수지', '    급료및임금수지',
#        '    투자소득수지', '    일반정부이전소득수지', '    기타부문이전소득수지'], dtype=object)

# %% [raw]
# 경상수지: Current Account Balance (CAB)
# 상품수지: Merchandise Trade Balance (MTB)
# 가공서비스수지: Processed Services Balance (PSB)
# 운송수지: Transport Balance (TB)
# 여행수지: Travel Balance (TB)
# 보험서비스수지: Insurance Services Balance (ISB)
# 지식재산권사용료수지: Intellectual Property Royalties Balance (IPRB)
# 통신,컴퓨터,정보서비스수지: Communication, Computer, Information Services Balance (CCISB)
# 기타사업서비스수지: Other Business Services Balance (OBSB)
# 정부서비스수지: Government Services Balance (GSB)
# 기타서비스수지: Other Services Balance (OSB)
# 급료및임금수지: Compensation of Employees Balance (CEB)
# 투자소득수지: Investment Income Balance (IIB)
# 일반정부이전소득수지: General Government Transfers Balance (GGTB)
# 기타부문이전소득수지: Other Sector Transfers Balance (OSTB)

# %%
export['nation_code'].unique()
# Out:
# array(['총계', '  미국', '  중국', '  일본', '  EU', '  동남아', '  중동', '  중남미',
#        '  기타'], dtype=object)

# %% [raw]
# 총계 : total
# 미국 : United States America (usa)
# 중국 : China (chn)
# 일본 : Japan (jp)
# EU : European Union (eu)
# 동남아 : Shoutheast Asia (sea)
# 중동 : Middle East (me)
# 중남미 : Latin America (latam)
# 기타 : and other things (etc)

# %%
# 'balacne_item', 'nation_code' 열의 값에 공백들 제거
export['balance_item'] = export['balance_item'].str.replace(' ','', regex=False)
export['nation_code'] = export['nation_code'].str.replace(' ','', regex=False)

# %% [markdown]
# ##### 국가별 경상수지 그래프

# %%
cab = export[export['balance_item'] == '경상수지']
cab_total = cab[cab['nation_code'] == '총계']
cab_total_melted = pd.melt(cab_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
cab_melted = pd.melt(cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')


fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=cab_total_melted, x='year', y='value', dashes=False, ax=axes[0])
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('연도별 총 경상수지')
plt.legend()

sns.lineplot(data=cab_melted, x='year', y='value', dashes=False, ax=axes[1])
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('연도별 총 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##### 통합 경상수지(연도별, 모든국가)

# %%
cab_filtered = cab[cab['nation_code'] != '총계']
cab_melted = pd.melt(cab_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=cab_melted, x='year', y='value', dashes=False, hue='nation_code')
plt.xlabel('연도')
plt.ylabel('dollor($1M)')
plt.title('연도별 국가별 총 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\200365704.py:13: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\200365704.py:13: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %%
usa = export[export['nation_code'] == '미국']
usa_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '미국')]

usa_melted = pd.melt(usa, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
usa_cab_melted = pd.melt(usa_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=usa_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#738FC0')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('미국의 연도별 총 경상수지')

sns.lineplot(data=usa_melted, x='year', y='value', dashes=False, ax=axes[1], color='#738FC0')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('미국의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
chn = export[export['nation_code'] == '중국']
chn_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '중국')]

chn_melted = pd.melt(chn, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
chn_cab_melted = pd.melt(chn_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=chn_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#E09D79')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('중국의 연도별 총 경상수지')

sns.lineplot(data=chn_melted, x='year', y='value', dashes=False, ax=axes[1], color='#E09D79')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('중국의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
jp = export[export['nation_code'] == '일본']
jp_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '일본')]

jp_melted = pd.melt(jp, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
jp_cab_melted = pd.melt(jp_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=jp_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#7AB88A')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('일본의 연도별 총 경상수지')

sns.lineplot(data=jp_melted, x='year', y='value', dashes=False, ax=axes[1], color='#7AB88A')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('일본의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
eu = export[export['nation_code'] == 'EU']
eu_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == 'EU')]

eu_melted = pd.melt(eu, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
eu_cab_melted = pd.melt(eu_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=eu_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#CD7479')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('EU의 연도별 총 경상수지')

sns.lineplot(data=eu_melted, x='year', y='value', dashes=False, ax=axes[1], color='#CD7479')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('EU의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sea = export[export['nation_code'] == '동남아']
sea_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '동남아')]

sea_melted = pd.melt(sea, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
sea_cab_melted = pd.melt(sea_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=sea_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#9B8FC2')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('동남아의 연도별 총 경상수지')

sns.lineplot(data=sea_melted, x='year', y='value', dashes=False, ax=axes[1], color='#9B8FC2')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('동남아의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
me = export[export['nation_code'] == '중동']
me_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '중동')]

me_melted = pd.melt(me, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
me_cab_melted = pd.melt(me_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=me_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#A89484')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('중동의 연도별 총 경상수지')

sns.lineplot(data=me_melted, x='year', y='value', dashes=False, ax=axes[1], color='#A89484')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('중동의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
latam = export[export['nation_code'] == '중남미']
latam_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '중남미')]

latam_melted = pd.melt(latam, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
latam_cab_melted = pd.melt(latam_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=latam_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#DDA2CE')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('중남미의 연도별 총 경상수지')

sns.lineplot(data=latam_melted, x='year', y='value', dashes=False, ax=axes[1], color='#DDA2CE')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('중남미의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
etc = export[export['nation_code'] == '기타']
etc_cab = export[(export['balance_item'] == '경상수지') & (export['nation_code'] == '기타')]

etc_melted = pd.melt(etc, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
etc_cab_melted = pd.melt(etc_cab, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(1, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=etc_cab_melted, x='year', y='value', dashes=False, ax=axes[0], color='#A3A3A5')
axes[0].set_xlabel('연도')
axes[0].set_ylabel('dollor($1M)')
axes[0].set_title('기타 다른국가들의 연도별 총 경상수지')

sns.lineplot(data=etc_melted, x='year', y='value', dashes=False, ax=axes[1], color='#A3A3A5')
axes[1].set_xlabel('연도')
axes[1].set_ylabel('dollor($1M)')
axes[1].set_title('기타 다른국가들의 연도별 총 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##### 수지별 그래프 통합

# %%
balance = export[export['balance_item'] != '경상수지']
balance_filtered = export[export['nation_code'] == '총계']
balance_melted = pd.melt(balance_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=balance_melted, x='year', y='value', dashes=False, hue='balance_item')
plt.xlabel('연도')
plt.ylabel('dollor($1M)')
plt.title('연도별 국가별 총 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\3735018257.py:14: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\3735018257.py:14: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %% [markdown]
# ##### 수지별 그래프

# %% [raw]
# 경상수지: Current Account Balance (CAB)
# 상품수지: Merchandise Trade Balance (MTB)
# 가공서비스수지: Processed Services Balance (PSB)
# 운송수지: Transport Balance (TransportB)
# 여행수지: Travel Balance (TravelB)
# 보험서비스수지: Insurance Services Balance (ISB)
# 지식재산권사용료수지: Intellectual Property Royalties Balance (IPRB)
# 통신,컴퓨터,정보서비스수지: Communication, Computer, Information Services Balance (CCISB)
# 기타사업서비스수지: Other Business Services Balance (OBSB)
# 정부서비스수지: Government Services Balance (GSB)
# 기타서비스수지: Other Services Balance (OSB)
# 급료및임금수지: Compensation of Employees Balance (CEB)
# 투자소득수지: Investment Income Balance (IIB)
# 일반정부이전소득수지: General Government Transfers Balance (GGTB)
# 기타부문이전소득수지: Other Sector Transfers Balance (OSTB)

# %%
cab = mtb = export[export['balance_item'] == '경상수지']
cab_filtered = cab[cab['nation_code'] == '총계']
cab_melted = pd.melt(cab_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
mtb = export[export['balance_item'] == '상품수지']
mtb_filtered = mtb[mtb['nation_code'] == '총계']
mtb_melted = pd.melt(mtb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
psb = export[export['balance_item'] == '가공서비스수지']
psb_filtered = psb[psb['nation_code'] == '총계']
psb_melted = pd.melt(psb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
transportb = export[export['balance_item'] == '운송수지']
transportb_filtered = transportb[transportb['nation_code'] == '총계']
transportb_melted = pd.melt(transportb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
travelb = export[export['balance_item'] == '여행수지']
travelb_filtered = travelb[travelb['nation_code'] == '총계']
travelb_melted = pd.melt(travelb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(2, 3, figsize=(18,12))
sns.set(style='darkgrid')

sns.lineplot(data=cab_melted, x='year', y='value', dashes=False, ax=axes[0,0], color='#F38FA3')
axes[0,0].set_xlabel('연도')
axes[0,0].set_ylabel('dollor($1M)')
axes[0,0].set_title('연도별 경상수지')

sns.lineplot(data=mtb_melted, x='year', y='value', dashes=False, ax=axes[0,1], color='#F09561')
axes[0,1].set_xlabel('연도')
axes[0,1].set_ylabel('dollor($1M)')
axes[0,1].set_title('연도별 상품수지')

sns.lineplot(data=psb_melted, x='year', y='value', dashes=False, ax=axes[0,2], color='#D1A761')
axes[0,2].set_xlabel('연도')
axes[0,2].set_ylabel('dollor($1M)')
axes[0,2].set_title('연도별 가공서비스수지')

sns.lineplot(data=transportb_melted, x='year', y='value', dashes=False, ax=axes[1,0], color='#BCB061')
axes[1,0].set_xlabel('연도')
axes[1,0].set_ylabel('dollor($1M)')
axes[1,0].set_title('연도별 운송수지')

sns.lineplot(data=travelb_melted, x='year', y='value', dashes=False, ax=axes[1,1], color='#A4B661')
axes[1,1].set_xlabel('연도')
axes[1,1].set_ylabel('dollor($1M)')
axes[1,1].set_title('연도별 여행수지')

fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
isb = export[export['balance_item'] == '보험서비스수지']
isb_filtered = isb[isb['nation_code'] == '총계']
isb_melted = pd.melt(isb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
iprb = export[export['balance_item'] == '지식재산권사용료수지']
iprb_filtered = isb[isb['nation_code'] == '총계']
iprb_melted = pd.melt(iprb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
ccisb = export[export['balance_item'] == '통신,컴퓨터,정보서비스수지']
ccisb_filtered = ccisb[ccisb['nation_code'] == '총계']
ccisb_melted = pd.melt(ccisb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
obsb = export[export['balance_item'] == '기타사업서비스수지']
obsb_filtered = obsb[obsb['nation_code'] == '총계']
obsb_melted = pd.melt(obsb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
gsb = export[export['balance_item'] == '정부서비스수지']
gsb_filtered = gsb[gsb['nation_code'] == '총계']
gsb_melted = pd.melt(gsb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(2, 3, figsize=(18,12))
sns.set(style='darkgrid')

sns.lineplot(data=isb_melted, x='year', y='value', dashes=False, ax=axes[0,0], color='#77BF60')
axes[0,0].set_xlabel('연도')
axes[0,0].set_ylabel('dollor($1M)')
axes[0,0].set_title('연도별 보험서비스수지')

sns.lineplot(data=iprb_melted, x='year', y='value', dashes=False, ax=axes[0,1], color='#5FBE97')
axes[0,1].set_xlabel('연도')
axes[0,1].set_ylabel('dollor($1M)')
axes[0,1].set_title('연도별 지식재산권사용료수지')

sns.lineplot(data=ccisb_melted, x='year', y='value', dashes=False, ax=axes[0,2], color='#62BCAF')
axes[0,2].set_xlabel('연도')
axes[0,2].set_ylabel('경상수지($1M)')
axes[0,2].set_title('연도별 통신, 컴퓨터, 정보서비스수지')

sns.lineplot(data=obsb_melted, x='year', y='value', dashes=False, ax=axes[1,0], color='#62BBBE')
axes[1,0].set_xlabel('연도')
axes[1,0].set_ylabel('dollor($1M)')
axes[1,0].set_title('연도별 기타사업서비스수지')

sns.lineplot(data=gsb_melted, x='year', y='value', dashes=False, ax=axes[1,1], color='#64B9D0')
axes[1,1].set_xlabel('연도')
axes[1,1].set_ylabel('dollor($1M)')
axes[1,1].set_title('연도별 정부서비스수지')

fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
osb = export[export['balance_item'] == '기타서비스수지']
osb_filtered = osb[osb['nation_code'] == '총계']
osb_melted = pd.melt(osb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
ceb = export[export['balance_item'] == '급료및임금수지']
ceb_filtered = ceb[ceb['nation_code'] == '총계']
ceb_melted = pd.melt(ceb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
iib = export[export['balance_item'] == '투자소득수지']
iib_filtered = iib[iib['nation_code'] == '총계']
iib_melted = pd.melt(iib_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
ggtb = export[export['balance_item'] == '일반정부이전소득수지']
ggtb_filtered = ggtb[ggtb['nation_code'] == '총계']
ggtb_melted = pd.melt(ggtb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
ostb = export[export['balance_item'] == '기타부문이전소득수지']
ostb_filtered = ostb[ostb['nation_code'] == '총계']
ostb_melted = pd.melt(ostb_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(2, 3, figsize=(18,12))
sns.set(style='darkgrid')

sns.lineplot(data=osb_melted, x='year', y='value', dashes=False, ax=axes[0,0], color='#66B4ED')
axes[0,0].set_xlabel('연도')
axes[0,0].set_ylabel('dollar($1M)')
axes[0,0].set_title('연도별 기타서비스수지')

sns.lineplot(data=ceb_melted, x='year', y='value', dashes=False, ax=axes[0,1], color='#AAA7F3')
axes[0,1].set_xlabel('연도')
axes[0,1].set_ylabel('dollar($1M)')
axes[0,1].set_title('연도별 급료및임금수지')

sns.lineplot(data=iib_melted, x='year', y='value', dashes=False, ax=axes[0,2], color='#D395F3')
axes[0,2].set_xlabel('연도')
axes[0,2].set_ylabel('dollar($1M)')
axes[0,2].set_title('연도별 투자소득수지')

sns.lineplot(data=ggtb_melted, x='year', y='value', dashes=False, ax=axes[1,0], color='#F282E7')
axes[1,0].set_xlabel('연도')
axes[1,0].set_ylabel('dollar($1M)')
axes[1,0].set_title('연도별 일반정부이전소득수지')

sns.lineplot(data=ostb_melted, x='year', y='value', dashes=False, ax=axes[1,1], color='#F389C5')
axes[1,1].set_xlabel('연도')
axes[1,1].set_ylabel('dollar($1M)')
axes[1,1].set_title('연도별 기타부문이전소득수지')

fig.delaxes(axes[1, 2])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##### 코로나 시기의 국가별 교류(2020~2022)

# %%
covid19 = export[['balance_item', 'nation_code', '20', '21', '22']]
covid19_csb = covid19[covid19['balance_item'] == '경상수지']
covid19_total = covid19_csb[covid19_csb['nation_code'] == '총계']
covid19_total_melted = pd.melt(covid19_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=covid19_total_melted, x='year', y='value', dashes=False)
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.title('코로나 시기동안 총 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\3158910120.py:15: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# ...

# %% [markdown]
# ##### 코로나 판데믹 시기의 다른국가와의 경상수지

# %%
covid19 = export[['balance_item', 'nation_code', '20', '21', '22']]

covid19_csb = covid19[covid19['balance_item'] == '경상수지']
covid19_total_filtered = covid19_csb[covid19_csb['nation_code'] != '총계']
covid19_total_filtered_melted = pd.melt(covid19_total_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=covid19_total_filtered_melted, x='year', y='value', dashes=False, hue='nation_code')
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.title('코로나 시기동안 모든 국가와의 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1321270462.py:16: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1321270462.py:16: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %%
covid19 = export[['balance_item', 'nation_code', '20', '21', '22']]

covid19_csb = covid19[covid19['balance_item'] == '경상수지']
covid19_total_filtered = covid19_csb[covid19_csb['nation_code'] != '총계']

labels = covid19_total_filtered['nation_code']
sizes = covid19_total_filtered[['20', '21', '22']].abs().sum(axis=1)

plt.figure(figsize=(12,8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, wedgeprops={'edgecolor': 'black'})
plt.title('코로나 시기동안 각 국가의 분포')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\661925382.py:14: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
# ...

# %% [markdown]
# * 코로나 시기동안 각 국가들의 분포
# 동남아(35.9%) > 중동(22.8%) > 미국(20.4%) > 일본(8.3%) > 중국(6.8%) > 기타(3.6%) > EU(1.7%) > 중남미(0.4%)

# %%
covid19_usa_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '미국')]
covid19_chn_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '중국')]
covid19_jp_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '일본')]
covid19_eu_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == 'EU')]

covid19_usa_total_melted = pd.melt(covid19_usa_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_chn_total_melted = pd.melt(covid19_chn_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_jp_total_melted = pd.melt(covid19_jp_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_eu_total_melted = pd.melt(covid19_eu_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(2, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=covid19_usa_total_melted, x='year', y='value', dashes=False, ax=axes[0,0], color='#738FC0')
axes[0,0].set_xlabel('연도')
axes[0,0].set_ylabel('dollar($1M)')
axes[0,0].set_title('코로나 시기동안 미국과의 경상수지')

sns.lineplot(data=covid19_chn_total_melted, x='year', y='value', dashes=False, ax=axes[0,1], color='#E09D79')
axes[0,1].set_xlabel('연도')
axes[0,1].set_ylabel('dollar($1M)')
axes[0,1].set_title('코로나 시기동안 중국과의 경상수지')

sns.lineplot(data=covid19_jp_total_melted, x='year', y='value', dashes=False, ax=axes[1,0], color='#7AB88A')
axes[1,0].set_xlabel('연도')
axes[1,0].set_ylabel('dollar($1M)')
axes[1,0].set_title('코로나 시기동안 일본과의 경상수지')

sns.lineplot(data=covid19_eu_total_melted, x='year', y='value', dashes=False, ax=axes[1,1], color='#CD7479')
axes[1,1].set_xlabel('연도')
axes[1,1].set_ylabel('dollar($1M)')
axes[1,1].set_title('코로나 시기동안 EU와의 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
covid19_sea_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '동남아')]
covid19_me_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '중동')]
covid19_latam_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '중남미')]
covid19_etc_total = covid19[(covid19['balance_item'] == '경상수지') & (covid19['nation_code'] == '기타')]

covid19_sea_total_melted = pd.melt(covid19_sea_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_me_total_melted = pd.melt(covid19_me_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_latam_total_melted = pd.melt(covid19_latam_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')
covid19_etc_total_melted = pd.melt(covid19_etc_total, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

fig, axes = plt.subplots(2, 2, figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=covid19_sea_total_melted, x='year', y='value', dashes=False, ax=axes[0,0], color='#9B8FC2')
axes[0,0].set_xlabel('연도')
axes[0,0].set_ylabel('dollar($1M)')
axes[0,0].set_title('코로나 시기동안 동남아와의 경상수지')

sns.lineplot(data=covid19_me_total_melted, x='year', y='value', dashes=False, ax=axes[0,1], color='#A89484')
axes[0,1].set_xlabel('연도')
axes[0,1].set_ylabel('dollar($1M)')
axes[0,1].set_title('코로나 시기동안 중동과의 경상수지')

sns.lineplot(data=covid19_latam_total_melted, x='year', y='value', dashes=False, ax=axes[1,0], color='#DDA2CE')
axes[1,0].set_xlabel('연도')
axes[1,0].set_ylabel('dollar($1M)')
axes[1,0].set_title('코로나 시기동안 중남미와의 경상수지')

sns.lineplot(data=covid19_etc_total_melted, x='year', y='value', dashes=False, ax=axes[1,1], color='#A3A3A5')
axes[1,1].set_xlabel('연도')
axes[1,1].set_ylabel('dollar($1M)')
axes[1,1].set_title('코로나 시기동안 다른 국가들과의 경상수지')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ##### 코로나 판데믹 시기의 다른국가와의 경상수지

# %%
deficit1 = export[['balance_item', 'nation_code', '19', '20', '21', '22']]
deficit1
# Out:
#     balance_item nation_code       19       20       21       22
# 0           경상수지          총계  59676.1  75902.2  85228.2  25828.6
# 1           경상수지          미국  19108.0  32798.5  45536.2  68969.1
# 2           경상수지          중국  25960.1  17247.9  23414.4  -8452.1
# 3           경상수지          일본 -19020.7 -20216.7 -22197.0 -17692.4
# 4           경상수지          EU  -5589.7  -5903.9   -627.5   5512.9
# ..           ...         ...      ...      ...      ...      ...
# 130   기타부문이전소득수지          EU    -55.2     50.8     73.9    -68.1
# 131   기타부문이전소득수지         동남아  -2404.2  -1694.8  -1216.4   -417.3
# 132   기타부문이전소득수지          중동     14.3    123.4     69.9    183.2
# 133   기타부문이전소득수지         중남미     47.5     60.5    -29.5     -1.1
# 134   기타부문이전소득수지          기타  -1329.0  -1058.1  -1009.0  -1208.9
#
# [135 rows x 6 columns]

# %%
# 경상수지 각국들 행만 선택
deficit1_nation = deficit1[(deficit1['nation_code'] != '총계')]

# 연도별 수치를 melt하여 시각화하기 쉽게 만듦
deficit1_nation_melted = deficit1_nation.melt(id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

# seaborn을 사용하여 lineplot 그리기
plt.figure(figsize=(12, 6))
sns.barplot(data=deficit1_nation_melted, x='year', y='value', hue='nation_code')
plt.title('코로나시기(2019-2022) 각 나라별 통계 추이')
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
# ...

# %% [markdown]
# * 3.3.1 단일 열: 데이터의 성격에 따른 다양한 차트 적용
# * 3.3.2 복수 열: 두개의 열간 연관관계 분석(Pair Plot 또는 Seaborn의 관련 지원 차트등)

# %% [markdown]
# #### 3.4 데이터 분석 결과도출

# %% [markdown]
# # 4. 탐색적연구

# %% [markdown]
# #### step0] 가설, 데이터분석을 위한 목적 대상 또는 중가설을 세워본다.

# %% [markdown]
# * 무역 흑자는 계속 증가 중일것이다.
# * 무역 흑자가 가장 많이 나는 나라는 중국일것이다.
# * 무역 적자가 가장 많이 나는 나라는 EU일것이다.
# * 무역 흑자가 가장 많이 나는 항목은 상품수지일것이다.
# * 무역 적자가 가장 많이 나는 항목은 보험서비스수지일것이다.
# * 코로나시기에 여행수지는 줄었을 것이고 상품수지, 운송수지는 늘었을것이다.
# * 사드배치 관련시기에는 중국과의 경상수지가 줄어들었을것이다.
# * 중국의 가파른 성장으로 중국과의 무역수지는 줄어들고 있을것이다.

# %% [markdown]
# #### Step1] 우선순위가 높은 가설을 구체화한다.
# * 예) 나이와 월급간에 상관관계가 있을 것이다. (40~60대 사이에서 급여가 가장 높을 것이다)

# %% [markdown]
# * 코로나 시기를 제외하면 경상수지가 지속적으로 증가하는 그래프를 그릴것이다.
# * 코로나 시기(2019~2022)는 경상수지가 줄어들었을것이다.
# * 사드배치 시기(2016~2017)는 중국과의 경상수지가 줄어들었을것이다.
# * 중국의 성장으로 중국과의 경상수지는 최근에 가파르게 줄어들었을것이다.

# %% [markdown]
# #### Step2] 가설증명: 데이터 재 구조화, 시각화를 통해 새로운 insight 및 정보를 습득 및 가설을 검증한다.
# * 예) 나이별 월급에 대한 평균값을 구하고 line차트로 시각화하여 추세를 파악하여 가설을 검증한다.

# %%
cab_filtered = cab[cab['nation_code'] != '총계']
cab_melted = pd.melt(cab_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=cab_melted, x='year', y='value', dashes=False, hue='nation_code')
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.title('연도별 국가별 총 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1921185836.py:13: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1921185836.py:13: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %% [markdown]
# * 2014년에 최대 경상수지를 기록하고 하락하는 경향세를 나타내고있다.
# * 중국의 가파른 성장으로 경상수지가 급격히 하락하는 경향을 나타내고있다.

# %%
covid19 = export[['balance_item', 'nation_code', '20', '21', '22']]

covid19_csb = covid19[covid19['balance_item'] == '경상수지']
covid19_total_filtered = covid19_csb[covid19_csb['nation_code'] != '총계']
covid19_total_filtered_melted = pd.melt(covid19_total_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=covid19_total_filtered_melted, x='year', y='value', dashes=False, hue='nation_code')
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.title('코로나 시기동안 모든 국가와의 경상수지')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1321270462.py:16: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1321270462.py:16: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %%
# 경상수지 각국들 행만 선택
deficit1_nation = deficit1[(deficit1['nation_code'] != '총계')]

# 연도별 수치를 melt하여 시각화하기 쉽게 만듦
deficit1_nation_melted = deficit1_nation.melt(id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

# seaborn을 사용하여 lineplot 그리기
plt.figure(figsize=(12, 6))
sns.barplot(data=deficit1_nation_melted, x='year', y='value', hue='nation_code')
plt.title('코로나시기(2019-2022) 각 나라별 통계 추이')
plt.xlabel('연도')
plt.ylabel('dollar($1M)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\1207558702.py:13: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
# ...

# %% [markdown]
# * 코로나시기 이전 하락하는 경향을 보이고 오히려 코로나시기에 경상수지가 올라가는 경향이있다.
# * 코로나가 끝난 2022년에 오히려 떨어지는 경향을 보였다.

# %%
balance = export[export['balance_item'] != '경상수지']
balance_filtered = export[export['nation_code'] == '총계']
balance_melted = pd.melt(balance_filtered, id_vars=['balance_item', 'nation_code'], var_name='year', value_name='value')

plt.figure(figsize=(12,8))
sns.set(style='darkgrid')

sns.lineplot(data=balance_melted, x='year', y='value', dashes=False, hue='balance_item')
plt.xlabel('연도')
plt.ylabel('dollor($1M)')
plt.title('연도별 모든 수지 통합')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\324469828.py:14: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\user\AppData\Local\Temp\ipykernel_8024\324469828.py:14: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# ...

# %% [markdown]
# * 가장 많은 수익을 나타내는 수지는 상품수지로 나타나며, 가장 많은 손해를 나타내는 수지는 기타부문이전소득으로 나타났다

# %% [markdown]
# #### Step3] 가설결론: 해당 가설에 대한 결론을 내린다.

# %% [markdown]
# * 중국의 성장으로 최근에 경상수지가 줄어든것은 사실
# * 코로나시기 줄어들었을것으로 예측되었던 경상수지는 오히려 올라가는 경향을보임
# * 사드배치시기 중국과의 경향수지는 더 큰폭으로 하락할 것으로 예측했으나 15년부터 보인하락세와 별차이가 없음
# * 경상수지 흑자가 가장 많이 나는 나라는 중국으로 추정했으나 동남아가 제일 컸고 최근 미국이 역전하였음
# * 경상수지 적자가 가장 많이 나는 나라는 EU로 추정했으나 중동이 가장 큰 것으로 파악함
# * 경상수지 흑자가 가장 많이 나는 부분을 상품수지로 예상하였고 사실로 파악함
# * 경상수지 적자가 가장 많이 나는 부분을 보험서비스수지로 예상하였으나 기타부문이전소득이라는 것을 알게됨

# %% [markdown]
# #### Step4] 탐색적연구 반복
# * 추가 가설 설정하고 우선순위 재조정
# * 시간 일정이 허락하는 범위내에서 Step1~Step3를 반복한다

# %% [markdown]
# #### Step5] 최종결론: 지금까지 진행했던 모든 탐색적연구의 결과를 반영하여 최종 결론을 내린다.

# %% [markdown]
# * 코로나 시기 이후 줄어든 경상수지 및 상품수지는 완만한 회복을 보이고 있으며, 사드배치시기 중국의 경향수지는 별 차이가 없었음
# * 코로나 시기 이전 15년 이후 경상수지는 감소가 시작했으며 오히려 코로나 시기에 경상수지는 증가함
# * 최근 가공서비스수지가 올라가는 경향이 있으며 상품수지와 비슷한 수준까지 올라와서 앞으로 가공서비스업이 전망이 좋아보임
# * 추가적인 분석을 위해선 국가별 수지를 파악하여 국가별 약점과 강점을 파악할 수 있을것으로 보임

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 데이터분석 적용 실습 템플릿

# %% [markdown]
# ## 필요한 모듈 import

# %% [markdown]
# ## 데이터 수집

# %%
# 데이터 소스를 확보하세요

# %% [markdown]
# ## 1. 초기데이터 확인

# %% [markdown]
# ### 1-1. 데이터스키마 확인

# %% [markdown]
# #### 각 열의 의미, 데이터의 의미해석관련 스펙 또는 메뉴얼을 확인 가능시 진행 하세요
# * A열: A열의 의미를 기술
# * B열: B열의 의미를 기술
# ...

# %% [markdown]
# ### 1-2. 데이터 기초정보 확인

# %% [markdown]
# * 사이즈, 데이터형, 기초통계항목등을 확인하세요

# %%
#df.shape
#df.info()

# %% [markdown]
# * 기초통계항목

# %%
# df.desribe()

# %% [markdown]
# ## 2. 데이터 정제

# %% [markdown]
# ### 2-1. 간단한 데이터 전처리

# %%
# 원본데이터로에서 읽기 가능한 형태로 데이터처리를 하세요. (열이름 변경, 형변환 등)

# %% [markdown]
# ### 2-2. 데이터 클리닝

# %%
# 결측치, 중복값, 이상치 처리등의 작업을 진행하세요

# %% [markdown]
# * 결측치

# %% [markdown]
#     - 결측치 열 확인

# %%
# missing_values = df.isnull().any()  
# column_missing_values = missing_values[ missing_values == True ]
# column_missing_values

# %% [raw]
#    - 결측값이 있는 모든 행 확인

# %%
# df.isnull().any(axis=1)

# %% [markdown]
# * 결측치 보정

# %% [raw]
#    - 열에 대하여 단일 값 보정

# %%
# df['나이'] = df['나이'].fillna(0)

# %% [raw]
#    - 데이터 프레임 전체에 단일 값 보정

# %%
# df = df.fillna(0)

# %% [markdown]
# * 중복값 삭제 (필요시)

# %% [raw]
#   - 모든 중복 행데이터 확인

# %%
# df[df.duplicated(keep=False)]

# %% [raw]
#   - 모든 중복 행데이터 삭제

# %%
# df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 3. 초기데이터 분석

# %% [markdown]
# ### 3.1. 데이터 정제후 데이터스키마 재확인

# %% [markdown]
# * 1-2 작업을 다시 해보세요.

# %% [markdown]
# ### 3.2 데이터 기초정보 정보 확인

# %% [markdown]
# * 최대값, 최소값, 평균값, 표준편차, 최빈값, 유일값, 결측치, 이상치 등의 정보를 재확인해 보세요

# %% [markdown]
# ### 3.3 시각화를 통한 데이터이해 심화

# %% [markdown]
# * 데이터의 성격에 따라 이해도를 올리기 위해 시각화가 필요한 데이터차트를 만들어 보세요.
#   (Seaborn 추천: 페어플롯, 막대차트, 파이차트, 라인차트, 히스토그램등..)
# * 시각화한 차트에 대한 분석

# %% [markdown]
# # 4. 탐색적연구

# %% [markdown]
# #### Step1] 가설: 데이터 분석을 위한 목적, 대상 또는 가설을 세워본다.
# * 예) 나이와 월급간에 상관관계가 있을 것이다. (40~60대 사이에서 급여가 가장 높을 것이다)

# %% [markdown]
# #### Step2] 가설증명: 데이터 재 구조화, 시각화를 통해 새로운 insight 및 정보를 습득 및 가설을 검증한다.
# * 예) 나이별 월급에 대한 평균값을 구하고 line차트로 시각화하여 추세를 파악하여 가설을 검증한다.

# %% [markdown]
# #### Step3] 가설결론: 해당 가설에 대한 결론을 내린다.

# %% [markdown]
# #### Step4] 탐색적연구 반복: 시간 일정이 허락하는 범위내에서 Step1~Step3를 반복한다.

# %% [markdown]
# #### Step5] 최종결론: 지금까지 진행했던 모든 탐색적연구의 결과를 반영하여 최종 결론을 내린다.
