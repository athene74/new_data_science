# %% [markdown]
# * URL은 Navar Developer 페이지에서 참고

# %% [markdown]
# ![image.png](attachment:ed1c00c7-7e0a-4e8b-b207-f26fb2d65972.png)

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = ""
client_secret = ""
# encText = urllib.parse.quote("가산디지털단지역 맛집")
encText = urllib.parse.quote("오대산")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Tue, 07 May 2024 10:31:14 +0900",
# 	"total":226592,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"평창 <b>오대산<\/b> 월정사 전나무숲길 입장료 주차장 가볼만한곳",
# 			"link":"https:\/\/blog.naver.com\/0watergirl0\/223435769324",
# 			"description":"이제 곧 부처님 오신 날이 다가오고 있어요 얼마 전 가족 여행을 갔다가 숙소 근처에 평창 <b>오대산<\/b>... 들었어요 #<b>오대산<\/b>국립공원 으로 들어가는데 한쪽에 자작나무가 가득하더라고요 어찌나 예쁜지 시간만 좀... ",
# 			"bloggername":"여행하는 엄마생활",
# 			"bloggerlink":"blog.naver.com\/0watergirl0",
# 			"postdate":"20240503"
# 		},
# 		{
# 			"title":"<b>오대산<\/b>맛집 월정사 입구 앞 신선한 나물 정식 추천",
# 			"link":"https:\/\/blog.naver.com\/hyungsuk1010\/223429610056",
# 			"description":"#<b>오대산<\/b>맛집 #월정사맛집 #나물정식 #<b>오대산<\/b>산촌 어머님을 모시고 <b>오대산<\/b> 구경을 오면서 들린 식당인데 괜찮았어요. 바로 <b>오대산<\/b> 산촌입니다. 식당 위치 § 상호명 : <b>오대산<\/b> 산촌 ● 주소 : 강원특별자치도 평창군... ",
# 			"bloggername":"여행에 미치다",
# 			"bloggerlink":"blog.naver.com\/hyungsuk1010",
# 			"postdate":"20240428"
# 		},
# 		{
# 			"title":"근로자의 날 <b>오대산<\/b> 구경",
# 			"link":"https:\/\/blog.naver.com\/lunaseed_\/223435992285",
# 			"description":"친구분과 <b>오대산<\/b>의 월정사와 상원사 구경을 간다고 하셔서, 나도 한번 따라가 보기로 했다. 은퇴하고 집에 있는 동생까지 해서 4명이서 가게 되었다. 아침 일찍 청량리역에서 KTX를 타고 진부(<b>오대산<\/b>)역에서 내려... ",
# 			"bloggername":"다시 한번 더",
# 			"bloggerlink":"blog.naver.com\/lunaseed_",
# 			"postdate":"20240504"
# 		},
# 		{
# 			"title":"[강원도] <b>오대산<\/b> 눈길을 걷다",
# 			"link":"https:\/\/blog.naver.com\/hwan_tae7129\/223362996279",
# 			"description":"여행자언니와 <b>오대산<\/b> 산행 결정 기차표 예매를 위해 코레일에 들어갔으나 전석 매진 예약 대기에... 1,563m <b>오대산<\/b> 정상 비로봉에 올라서기까지 힘들었다. 적멸보궁 아래까지 수많은 계단길이 끝나면 그 다음... ",
# 			"bloggername":"고마리의 행복한 세상",
# 			"bloggerlink":"blog.naver.com\/hwan_tae7129",
# 			"postdate":"20240223"
# 		},
# 		{
# 			"title":"<b>오대산<\/b> 월정사 맛집 - <b>오대산<\/b> 가마솥 식당 (내돈내산)",
# 			"link":"https:\/\/blog.naver.com\/minicar\/223380770142",
# 			"description":"강원도 여행을 하다보면 자주 찾게 되는 곳이 <b>오대산<\/b> 월정사지역이다. 전나무 숲길도 있고 월정사에서... 서 계신 분이 사장님인데 직접 <b>오대산<\/b>을 누비며 다양한 식물재료들을 캐오신다고 한다. 앉아서 나물... ",
# 			"bloggername":"Mini's 조금 특별한 하루",
# 			"bloggerlink":"blog.naver.com\/minicar",
# 			"postdate":"20240312"
# 		},
# 		{
# 			"title":"<b>오대산<\/b> 맛집 토박이가 운영하는 정갈한 나물 한식",
# 			"link":"https:\/\/blog.naver.com\/xfitndiet\/223421340792",
# 			"description":"좋은 <b>오대산<\/b> 맛집 산촌 지금부터 공개해 볼까 합니다 영업정보 <b>오대산<\/b> 산촌 주소 강원 평창군 진부면 <b>오대산<\/b>로 152 전화번호 033-333-7975 영업시간 매일 08시 20분 ~ 오후 7시 라스트 오더 7시 30분 수많은 연예인들이... ",
# 			"bloggername":"한량의 즐거운 소비 생활",
# 			"bloggerlink":"blog.naver.com\/xfitndiet",
# 			"postdate":"20240420"
# 		},
# 		{
# 			"title":"발왕산 케이블카, 평창 카페 감자창고, <b>오대산<\/b> 월정사 전나무숲길",
# 			"link":"https:\/\/blog.naver.com\/hyonitrip\/223429165272",
# 			"description":"리조트에 사람 되게 없다고 생각했는데 여기 다 모여있었네 내려갈 땐 살짝 쫄보가 된 블루ㅋㅋ 약간 무서워하는 듯 좋아해 좋아하는데 싫어해 @<b>오대산<\/b> 월정사 전나무 숲길 케이블카만 타고 헤어지기... ",
# 			"bloggername":"원나잇효니트립",
# 			"bloggerlink":"blog.naver.com\/hyonitrip",
# 			"postdate":"20240427"
# 		},
# 		{
# 			"title":"대포항 해덕이네 (횟집), <b>오대산<\/b> 월정사 전나무숲길",
# 			"link":"https:\/\/blog.naver.com\/lefy\/223432830247",
# 			"description":"<b>오대산<\/b>은 지금도 많이 피던데 겹벚꽃을 찾아오다가 본 곳으로 향한다. 큰 식당 앞에 너른 주차공간이... 픽업하고 <b>오대산<\/b> 옛날길 따라 진고개 넘어 <b>오대산<\/b> 월정사 전나무숲길 산책 월정사 주차장에서 월정사로... ",
# 			"bloggername":"그래도 아직은...",
# 			"bloggerlink":"blog.naver.com\/lefy",
# 			"postdate":"20240501"
# 		},
# 		{
# 			"title":"상원사에서 오르는 <b>오대산<\/b> 비로봉과 월정사 전나무숲길 - 강원... ",
# 			"link":"https:\/\/blog.naver.com\/wawoo37\/223361760485",
# 			"description":"평지로 쉽게 다녔으니 오늘은 숨 좀 차게 오르막을 가보자 오늘의 픽은 <b>오대산<\/b> 비로봉 근처에 월정사도... 23일의 하루 시작한다 월정사를 가려 했는데 주변 지도를 보니 나름 유명한 <b>오대산<\/b>이 눈에 띈다... ",
# 			"bloggername":"유유자적",
# 			"bloggerlink":"blog.naver.com\/wawoo37",
# 			"postdate":"20240223"
# 		},
# 		{
# 			"title":"만석닭강정,강원도막걸리술빵,소금강,<b>오대산<\/b>국립공원",
# 			"link":"https:\/\/blog.naver.com\/tanyo35\/223416200602",
# 			"description":"#속초중앙시작 #속초바삭튀밥 #만석닭강정 #강원도막걸리술빵 #소금강코스 #<b>오대산<\/b>국립공원... 기억이....어쩌다가 <b>오대산<\/b> 국립공원 소금강 코스로 출발 ㅋㅋㅋㅋㅋㅋㅋㅋ 나 베스트 드라이버 도착 평일이고 살짝... ",
# 			"bloggername":"복잡한 세상",
# 			"bloggerlink":"blog.naver.com\/tanyo35",
# 			"postdate":"20240415"
# 		}
# 	]
# }
