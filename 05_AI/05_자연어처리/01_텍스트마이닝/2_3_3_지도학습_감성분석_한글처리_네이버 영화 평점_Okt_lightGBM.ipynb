# %%
import pandas as pd

train_df = pd.read_csv('ratings_train.txt', sep='\t')
train_df.head(10)
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# 5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.      0
# 6   7797314                              원작의 긴장감을 제대로 살려내지못했다.      0
# 7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0
# 8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1

# %%
train_df['label'].value_counts( )
# Out:
# label
# 0    75173
# 1    74827
# Name: count, dtype: int64

# %%
import re

train_df = train_df.fillna(' ')
# 정규 표현식을 이용하여 숫자를 공백으로 변경(정규 표현식으로 \d 는 숫자를 의미함.) 
train_df['document'] = train_df['document'].apply( lambda x : re.sub(r"\d+", " ", x) )

# 테스트 데이터 셋을 로딩하고 동일하게 Null 및 숫자를 공백으로 변환
test_df = pd.read_csv('ratings_test.txt', sep='\t')
test_df = test_df.fillna(' ')
test_df['document'] = test_df['document'].apply( lambda x : re.sub(r"\d+", " ", x) )

# id 칼럼 삭제 수행
train_df.drop('id', axis=1, inplace=True) 
test_df.drop('id', axis=1, inplace=True)

# %%
# konlpy: 한국어 자연어 처리를 위한 상위 모듈
# from konlpy.tag import Twitter
from konlpy.tag import Okt

# Okt: 한국어 형태소를 분석하기 위한 형태소 분석기, Twitter의 상위 버전
okt = Okt()
def tw_tokenizer(text):
    # 입력 인자로 들어온 text 를 형태소 단어로 토큰화 하여 list 객체 반환
    tokens_ko = okt.morphs(text)
    return tokens_ko

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Twitter 객체의 morphs( ) 객체를 이용한 tokenizer를 사용. ngram_range는 (1,2) 
# min_df:  특정단어가 전체 문서에서 인자값보다 작다면 해당 단어는 무시한다.
# 예) 3이면 특정단어는 최소한 3이상 나와야 분석이 가능하다.
# max_df: 특정단어가 전체 문서의 90%이상 등장하면 해당 단어는 무시한다.
tfidf_vect = TfidfVectorizer(tokenizer=tw_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9)
tfidf_vect.fit(train_df['document'])
tfidf_matrix_train = tfidf_vect.transform(train_df['document'])
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
tfidf_matrix_test = tfidf_vect.transform(test_df['document'])

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# LGBM 분류기 초기화
lgbm = LGBMClassifier(random_state=0, n_jobs=-1)

#하이퍼파라메터의 분포를 정의
param_dist = {
    'num_leaves': sp_randint(6, 50), 
    'min_child_samples': sp_randint(100, 500), 
    'min_child_weight': [1e-5, 1e-2, 0.1, 1, 100], 
    'subsample': sp_uniform(loc=0.2, scale=0.8), 
    'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
    'reg_alpha': [0, 1e-1, 1, 2, 100],
    'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 100]
}

# param_dist = {
#     'num_leaves': sp_randint(20, 40),  # 너무 크지 않은 범위로 조정
#     'min_child_samples': sp_randint(50, 150),  # 더 낮은 범위로 조정하여 더 많은 데이터 샘플 고려
#     'min_child_weight': [0.001, 0.01, 0.1, 1],  # 더 세밀한 범위
#     'subsample': sp_uniform(loc=0.7, scale=0.3),  # 더 많은 샘플 사용
#     'colsample_bytree': sp_uniform(loc=0.5, scale=0.5),  # 더 많은 피처 사용
#     'reg_alpha': [0, 0.1, 0.5, 1],  # L1 정규화 조정
#     'reg_lambda': [0, 0.1, 1, 5],  # L2 정규화 조정
#     'max_depth': sp_randint(3, 15)  # 최대 깊이 추가
# }


# RandomizedSearchCV 객체 생성
rnd_search = RandomizedSearchCV(estimator=lgbm, param_distributions=param_dist, 
                                n_iter=100, scoring='accuracy', cv=3, random_state=0, verbose=1)

# 모델 학습
rnd_search.fit(tfidf_matrix_train, train_df['label'])

print('Best parameters found: ', rnd_search.best_params_)
print('Best accuracy found: ', rnd_search.best_score_)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086159 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 156038
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 974
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.085131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 157338
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 984
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088202 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 157488
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 987
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 122800
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 607
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.059918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 123326
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 608
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061493 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 123162
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 607
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.117724 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 191468
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1578
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.143657 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 192822
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1593
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119581 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 192260
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1581
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056816 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 122685
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 606
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.090542 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 122982
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 605
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.058386 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 123162
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 607
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.076697 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 147129
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 859
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.077173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 147149
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 853
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.113349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 146790
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 849
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 122340
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 603
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052995 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 122867
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 604
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083852 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 122932
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 605
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.137458 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 183905
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1425
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.093418 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 184949
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1434
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.130068 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 185151
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1437
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.082104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 119057
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 575
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 120990
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 588
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120233
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 582
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.126110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 171026
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.149645 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 170781
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1184
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.159884 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 171628
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057836 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 132079
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 694
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.060583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 131627
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 685
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089955 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133084
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 699
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 104249
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 464
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053739 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 105870
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 473
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.084010 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 105627
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 472
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.116493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176384
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1287
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 177043
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1289
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112589 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 176394
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1277
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.080017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 113158
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 528
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053913 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 113875
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 531
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.078129 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 114331
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 535
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.050128 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 132483
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 698
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 132334
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 692
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070741 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 133286
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 701
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095240 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151318
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 911
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.081617 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 152044
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 914
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 152340
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 918
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 125029
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 627
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 126244
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 634
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127082
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 642
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.114510 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 193154
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1614
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.179595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 194737
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1634
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.121052 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 194035
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1619
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.157774 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 195687
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1670
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.116083 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 197140
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1687
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 196593
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1675
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.080527 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 173458
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1237
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 173339
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.115705 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 173398
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1226
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049980 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 112633
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 524
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052361 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 112954
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 524
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.080735 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 113804
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 531
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037736 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 108959
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 497
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 109015
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 495
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059855 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 109742
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 501
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063080 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 98160
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 424
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 98576
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 425
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041764 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 98471
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 425
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 98160
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 424
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067727 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 98576
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 425
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040700 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 98471
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 425
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 106982
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 483
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.064707 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 108027
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 488
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049759 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 107209
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 483
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 141267
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 791
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 142324
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 797
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 142307
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 797
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053774 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 118817
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 573
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.084085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 120270
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 582
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055965 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 119633
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 577
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.110129 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 188798
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1522
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.161167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 190269
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1540
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.151632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 189873
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1531
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.080839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153012
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 933
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 154350
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 944
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.083605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 153872
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 938
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057609 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 110890
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 511
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 110668
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 507
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037873 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 111117
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 511
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058322 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 96546
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 414
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060751 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 97126
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 416
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049489 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 96540
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 413
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.135917 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 208030
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1967
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.216128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 209536
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1985
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.131869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 208469
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 1961
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.107868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 147956
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 869
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 148221
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 866
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.108910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 148116
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 865
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038937 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 94901
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 404
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49885, number of negative: 50115
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039505 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 95648
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 407
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498850 -> initscore=-0.004600
# [LightGBM] [Info] Start training from score -0.004600
# [LightGBM] [Info] Number of positive: 49884, number of negative: 50116
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 95886
# [LightGBM] [Info] Number of data points in the train set: 100000, number of used features: 409
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498840 -> initscore=-0.004640
# [LightGBM] [Info] Start training from score -0.004640
# [LightGBM] [Info] Number of positive: 74827, number of negative: 75173
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.286466 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 331044
# [LightGBM] [Info] Number of data points in the train set: 150000, number of used features: 3277
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.498847 -> initscore=-0.004613
# [LightGBM] [Info] Start training from score -0.004613
# Best parameters found:  {'colsample_bytree': 0.9754999618211335, 'min_child_samples': 106, 'min_child_weight': 0.01, 'num_leaves': 44, 'reg_alpha': 2, 'reg_lambda': 1, 'subsample': 0.6606009296358979}
# Best accuracy found:  0.7911266666666666

# %%
# 테스트 데이터 세트에 대한 예측 수행
best_estimator = rnd_search.best_estimator_
preds = best_estimator.predict(tfidf_matrix_test)

# %%
from sklearn.metrics import accuracy_score, f1_score


accuracy = accuracy_score(test_df['label'], preds)
f1 = f1_score(test_df['label'], preds)

print(f'lightGBM 정확도: {accuracy:.4f}')
print(f'lightGBM F1-스코어: {f1:.4f}')
# Out:
# lightGBM 정확도: 0.7961
# lightGBM F1-스코어: 0.7901
