# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Input

# 1.1 데이터셋 생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# %%
# 1.2 입력값 이해하기
import matplotlib.pyplot as plt

# 데이터셋 시각화하기
plt.scatter(x_train, y_train, alpha=0.5)
plt.title('Scatter plot of the training data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Input(shape=(1,)))  # 'Input' 레이어로 입력 형태 정의
# model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(optimizer='adam', loss='mse')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

# 5. 학습과정 살펴보기
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])
plt.ylim(0.0, 1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# 6. 모델 평가하기
loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss : ' + str(loss))
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1381
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.4732
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0681
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0398
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0285
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0226
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0190
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0154
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0134
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0108
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0103
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0092
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0087
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0092
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0085
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0090
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0089
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0092
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.0088
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0089
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0087
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0088
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.0093
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0090
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0091
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0085
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0090
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0092
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0088
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0089
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0091
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0093
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0087
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0092
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.0090
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0090
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0091
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0089
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0090
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0096
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0092
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0091
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0090
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103
# loss : 0.01015565637499094

# %%
# 7. 예측하기
input_value = np.array([[0.5]])  # 특정 특성 값을 포함하는 2D 배열
predicted_value = model.predict(input_value)
print(f'입력 값: {input_value.flatten()[0]}')
print(f'예측된 출력 값: {predicted_value.flatten()[0]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 입력 값: 0.5
# 예측된 출력 값: 1.1752450466156006
