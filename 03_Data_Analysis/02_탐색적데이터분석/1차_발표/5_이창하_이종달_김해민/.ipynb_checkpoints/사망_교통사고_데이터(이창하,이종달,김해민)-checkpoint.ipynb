# %% [markdown]
# ## 주요절차

# %% [markdown]
# ### 데이터 수집

# %% [markdown]
# * 데이터 소스 명시

# %% [markdown]
# ### 1. 초기데이터 확인

# %% [markdown]
# #### 1-1. 데이터딕셔너리(각 열의 의미, 데이터의 의미해석관련 스펙 또는 메뉴얼) 확인
# #### 1-2 데이터 기초정보 확인 (사이즈, 열이름, 데이터형)

# %% [markdown]
# * 기초통계정보 확인

# %% [raw]
# 기초 통계값 확인 ( df.describe() )
# [수치형 데이터]
#
# => 수치데이터로서 의미가 는지 판단?
# => 의미가 있는(예: 키, 몸무게, 가격등) 열에 대해 아래 작업 진행  분석
#  - 확인해야 할 사항    수치상
# mean, min, 1q, 2q(중위값), 3q,게, 가격
#  - 시각화
#   히스토그램, 박스플롯 (바이올린플롯)
#  - 이상치 유무 확인
#  - 이상치가 있다면 보정방식을 선택
#   (예: 삭제, 포함)
# - 기초통계값과, 차트 재확인 (이상
# [보정  데이터]유무 확인)
# - 문자열
#  => unique의 결과값에서 파이차트나 막대차트로 그릴수  - 있는 열이 있는지 확인
#  10개미만은 파이차트,  - 도우넛차트 그리기에 용이
#  10개상위 은 파이차트, 막대차트(Top3,5,10 등을 도출.. 그리고 형 데이터나하위 데이터3,5,10)
#
# * 수치 문자 중에 범위화 할
#  예)수 있는 열이 있는지 확인해 보자
#  가격=> 초고가, 고가,위 작업은  일반, 저가
#  주소 추후 진행할 수 있다.pply 함수를 통해
# ly 함수를 통해

# %% [markdown]
# ### 2. 데이터 정제

# %% [markdown]
# #### 2.1. 원본데이터에서 분석가능한 형태로 데이터 전처리 (형변환, 열이름 변경등)
# #### 2.2. 데이터 클리닝: 이상치, 결측치처리

# %% [markdown]
# ### 3. 초기데이터 분석

# %% [markdown]
# #### 3.1 데이터 정제후 데이터딕셔너리 재확인
# #### 3.2 기초통계 정보 확인 (최대값, 최소값, 평균값, 표준편차, 최빈값, 유일값 등)
# #### 3.3 시각화를 통한 데이터이해 심화

# %% [markdown]
# * 3.3.1 단일 열: 데이터의 성격에 따른 다양한 차트 적용
# * 3.3.2 복수 열: 두개의 열간 연관관계 분석(Pair Plot 또는 Seaborn의 관련 지원 차트등)

# %% [markdown]
# #### 3.4 데이터 분석 결과도출

# %% [markdown]
# # 4. 탐색적연구

# %% [markdown]
# #### Step0] 데이터 분석을 위한 목적, 대상 또는 가설을 세워본다. 주요가설 도출후 우선순위를 설정한다.

# %% [markdown]
# #### Step1] 우선순위가 높은 가설을 구체화 한다.
# * 예) 나이와 월급간에 상관관계가 있을 것이다. (40~60대 사이에서 급여가 가장 높을 것이다)

# %% [markdown]
# #### Step2] 가설증명: 데이터 재 구조화, 시각화를 통해 새로운 insight 및 정보를 습득 및 가설을 검증한다.
# * 예) 나이별 월급에 대한 평균값을 구하고 line차트로 시각화하여 추세를 파악하여 가설을 검증한다.

# %% [markdown]
# #### Step3] 가설결론: 해당 가설에 대한 결론을 내린다.

# %% [markdown]
# #### Step4] 탐색적연구 반복:
# * 추가 가설 설정하고 가설의 우선순위를 재조정한다.
# * 시간 일정이 허락하는 범위내에서 Step1~Step3를 반복한다.

# %% [markdown]
# #### Step5] 최종결론: 지금까지 진행했던 모든 탐색적연구의 결과를 반영하여 최종 결론을 내린다.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 데이터분석 적용 실습 템플릿

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 필요한 모듈 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# ## 데이터 수집

# %%
# 데이터 소스를 확보하세요
file_path = '도로교통공단_사망 교통사고 정보_20231231.csv'
df = pd.read_csv(file_path,encoding='cp949')

# %% [markdown]
# ## 1. 초기데이터 확인

# %% [markdown]
# ### 1-1. 데이터스키마 확인

# %% [markdown]
# #### 각 열의 의미, 데이터의 의미해석관련 스펙 또는 메뉴얼을 확인 가능시 진행 하세요
# * 발생년 : 사망사고가 발생한 년도
# * 발생년월일시 : 사망사고가 발생한 일시
# * 주야 : 사망사고가 발생한 주야
# * 요일 : 사망사고가 발생한 요일
# * 사망자수 : 발생한 사망자수
# * 부상자수 : 발생한 부상자수
# * 중상자수 : 발생한 중상자수
# * 경상자수 : 발생한 경상자수
# * 부상신고자수 : 교통사고 신고자수
# * 발생지시도 : 교통사고가 발생한 지역
# * 사고요형 : 교통사고 사고유형
# * 사해자 법규위반 : 교통사고 가해자가 위한반 법규
# * 도로형태 : 교통사고가 발생한 도로의 형태
# * 가해자_당사자종별 : 발생한 교통사고의 가해자 차량종
# * 피해자_당사자종별 : 발생한 교통사고의 피해자 종
# * 경도 : 교통사고가 발생한 경도
# * 위도 : 교통사고가 발생한 위도

# %% [markdown]
# ### 1-2. 데이터 기초정보 확인

# %% [markdown]
# * 사이즈, 데이터형, 기초통계항목등을 확인하세요

# %%
#df.shape
#df.info()

# %%
df.shape
# Out:
# (2468, 23)

# %%
df.head()
# Out:
#     발생년            발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0  2023  2023-01-01 07:00  주  일     1     0     0     0       0    충북  ...
# 1  2023  2023-01-01 07:00  주  일     1     0     0     0       0    경남  ...
# 2  2023  2023-01-01 10:00  주  일     1     0     0     0       0    경북  ...
# 3  2023  2023-01-01 14:00  주  일     1     0     0     0       0    경기  ...
# 4  2023  2023-01-01 18:00  야  일     1     0     0     0       0    경기  ...
#
#     사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별    발생위치X    발생위치Y  \
# 0     기타  안전운전 의무 불이행      단일로  기타단일로      건설기계       보행자  1015896  1885475
# 1     기타  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음  1089954  1651437
# 2     기타  안전운전 의무 불이행      단일로  기타단일로       화물차       보행자  1181459  1784728
# 3  공작물충돌  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음   943961  1915763
# 4     기타  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음   974470  1970403
#
#            경도         위도
# 0  127.678579  36.967573
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2468 entries, 0 to 2467
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   발생년        2468 non-null   int64
#  1   발생년월일시     2468 non-null   object
#  2   주야         2468 non-null   object
#  3   요일         2468 non-null   object
#  4   사망자수       2468 non-null   int64
#  5   부상자수       2468 non-null   int64
#  6   중상자수       2468 non-null   int64
#  7   경상자수       2468 non-null   int64
#  8   부상신고자수     2468 non-null   int64
#  9   발생지시도      2468 non-null   object
#  10  발생지시군구     2468 non-null   object
#  11  사고유형_대분류   2468 non-null   object
#  12  사고유형_중분류   2468 non-null   object
#  13  사고유형       2468 non-null   object
#  14  가해자법규위반    2468 non-null   object
#  15  도로형태_대분류   2468 non-null   object
#  16  도로형태       2468 non-null   object
#  17  가해자_당사자종별  2468 non-null   object
#  18  피해자_당사자종별  2468 non-null   object
# ...

# %% [markdown]
# * 기초통계항목

# %%
# df.desribe()

# %%
df.describe()
# Out:
#           발생년         사망자수         부상자수         중상자수         경상자수  \
# count  2468.0  2468.000000  2468.000000  2468.000000  2468.000000
# mean   2023.0     1.033630     0.548217     0.199757     0.314830
# std       0.0     0.224384     2.080977     0.730515     1.667591
# min    2023.0     1.000000     0.000000     0.000000     0.000000
# 25%    2023.0     1.000000     0.000000     0.000000     0.000000
# 50%    2023.0     1.000000     0.000000     0.000000     0.000000
# 75%    2023.0     1.000000     0.000000     0.000000     0.000000
# max    2023.0     5.000000    54.000000    13.000000    54.000000
#
#             부상신고자수         발생위치X         발생위치Y           경도           위도
# count  2468.000000  2.468000e+03  2.468000e+03  2468.000000  2468.000000
# mean      0.033630  1.007418e+06  1.817719e+06   127.580210    36.353688
# std       0.267257  7.758019e+04  1.173355e+05     0.860795     1.058923
# min       0.000000  7.507900e+05  1.471218e+06   124.663639    33.226256
# ...

# %%
df.describe(include='object')
# Out:
#                   발생년월일시    주야    요일 발생지시도 발생지시군구 사고유형_대분류 사고유형_중분류  사고유형  \
# count               2468  2468  2468  2468   2468     2468     2468  2468
# unique              2118     2     7    17    205        4       15    16
# top     2023-08-26 05:00     주     금    경기     서구      차대차       기타    기타
# freq                   4  1359   387   489     54      997      605   605
#
#             가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별
# count          2468     2468   2468      2468      2468
# unique            7        5     11        12        14
# top     안전운전 의무 불이행      단일로  기타단일로       승용차       보행자
# freq           1713     1482   1340      1141       849

# %% [markdown]
# ## 2. 데이터 정제

# %% [markdown]
# ### 2-1. 간단한 데이터 전처리

# %%
# 원본데이터로에서 읽기 가능한 형태로 데이터처리를 하세요. (열이름 변경, 형변환 등)

# %%
df2 = df[['발생년월일시','사망자수','경도','위도','주야','요일','발생지시도','사고유형_대분류','사고유형_중분류','사고유형','가해자법규위반','도로형태_대분류','도로형태','가해자_당사자종별','피해자_당사자종별']]

# %%
df_cars = {
    '발생지시도' : ['서울','부산','대구','인천','광주','대전','울산','세종','경기','충북','충남','전남','경북','경남','제주','강원','전북'],
    '등록차량대수' : [3187055,1542198, 1259725,1743821,727549,731347,603871,200342,6583777,943489,1262413,1262308,1542663,1962310,708315,871904,998388]
}
df3 = pd.DataFrame(df_cars)

# %%
df4 = pd.merge(df2, df3, on='발생지시도')

# %%
df4.head()
# Out:
#              발생년월일시  사망자수          경도         위도 주야 요일 발생지시도 사고유형_대분류  \
# 0  2023-01-01 07:00     1  127.678579  36.967573  주  일    충북     차대사람
# 1  2023-01-04 18:00     1  128.209572  37.120054  야  수    충북     차대사람
# 2  2023-01-11 06:00     1  127.306667  36.603237  주  수    충북     차대사람
# 3  2023-01-12 10:00     1  127.482529  36.631862  주  목    충북      차대차
# 4  2023-01-25 01:00     1  127.783404  37.097347  야  수    충북     차량단독
#
#   사고유형_중분류     사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별  등록차량대수
# 0       기타       기타  안전운전 의무 불이행      단일로  기타단일로      건설기계       보행자  943489
# 1      횡단중      횡단중           기타      단일로  기타단일로       승용차       보행자  943489
# 2      횡단중      횡단중  안전운전 의무 불이행      단일로  기타단일로       화물차       보행자  943489
# 3     정면충돌     정면충돌       중앙선 침범      교차로  교차로부근       승용차       승용차  943489
# 4     도로이탈  도로이탈 추락  안전운전 의무 불이행      단일로  기타단일로       화물차        없음  943489

# %% [markdown]
# ### 2-2. 데이터 클리닝

# %%
# 결측치, 중복값, 이상치 처리등의 작업을 진행하세요

# %% [markdown]
# * 결측치

# %% [markdown]
#     - 결측치 열 확인

# %%
# missing_values = df.isnull().any()  
# column_missing_values = missing_values[ missing_values == True ]
# column_missing_values

# %%
missing_values = df2.isnull().any()  
column_missing_values = missing_values[ missing_values == True ]
column_missing_values
# Out:
# Series([], dtype: bool)

# %% [raw]
#    - 결측값이 있는 모든 행 확인

# %%
# df.isnull().any(axis=1)

# %% [markdown]
# * 결측치 보정

# %% [raw]
#    - 열에 대하여 단일 값 보정

# %%
# df['나이'] = df['나이'].fillna(0)

# %% [raw]
#    - 데이터 프레임 전체에 단일 값 보정

# %%
# df = df.fillna(0)

# %% [markdown]
# * 중복값 삭제 (필요시)

# %% [raw]
#   - 모든 중복 행데이터 확인

# %%
# df[df.duplicated(keep=False)]

# %%
df2[df2.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [발생년월일시, 사망자수, 경도, 위도, 주야, 요일, 발생지시도, 사고유형_대분류, 사고유형_중분류, 사고유형, 가해자법규위반, 도로형태_대분류, 도로형태, 가해자_당사자종별, 피해자_당사자종별]
# Index: []

# %% [raw]
#   - 모든 중복 행데이터 삭제

# %%
# df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 3. 초기데이터 분석

# %% [markdown]
# ### 3.1. 데이터 정제후 데이터스키마 재확인

# %% [markdown]
# * 1-2 작업을 다시 해보세요.

# %%
df2.head()
# Out:
#              발생년월일시  사망자수          경도         위도 주야 요일 발생지시도 사고유형_대분류  \
# 0  2023-01-01 07:00     1  127.678579  36.967573  주  일    충북     차대사람
# 1  2023-01-01 07:00     1  128.484013  34.853623  주  일    경남     차량단독
# 2  2023-01-01 10:00     1  129.514309  36.042531  주  일    경북     차대사람
# 3  2023-01-01 14:00     1  126.868199  37.239046  주  일    경기     차량단독
# 4  2023-01-01 18:00     1  127.210265  37.732883  야  일    경기     차량단독
#
#   사고유형_중분류   사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별
# 0       기타     기타  안전운전 의무 불이행      단일로  기타단일로      건설기계       보행자
# 1       기타     기타  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음
# 2       기타     기타  안전운전 의무 불이행      단일로  기타단일로       화물차       보행자
# 3    공작물충돌  공작물충돌  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음
# 4       기타     기타  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2468 entries, 0 to 2467
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   발생년월일시     2468 non-null   object
#  1   사망자수       2468 non-null   int64
#  2   경도         2468 non-null   float64
#  3   위도         2468 non-null   float64
#  4   주야         2468 non-null   object
#  5   요일         2468 non-null   object
#  6   발생지시도      2468 non-null   object
#  7   사고유형_대분류   2468 non-null   object
#  8   사고유형_중분류   2468 non-null   object
#  9   사고유형       2468 non-null   object
#  10  가해자법규위반    2468 non-null   object
#  11  도로형태_대분류   2468 non-null   object
#  12  도로형태       2468 non-null   object
#  13  가해자_당사자종별  2468 non-null   object
#  14  피해자_당사자종별  2468 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 289.3+ KB

# %%
times = df2['발생년월일시'].str.split(' ')
times
df2['발생시간'] = times.str[-1]
df2.head(5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1524\3516527589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['발생시간'] = times.str[-1]
#              발생년월일시  사망자수          경도         위도 주야 요일 발생지시도 사고유형_대분류  \
# 0  2023-01-01 07:00     1  127.678579  36.967573  주  일    충북     차대사람
# 1  2023-01-01 07:00     1  128.484013  34.853623  주  일    경남     차량단독
# 2  2023-01-01 10:00     1  129.514309  36.042531  주  일    경북     차대사람
# 3  2023-01-01 14:00     1  126.868199  37.239046  주  일    경기     차량단독
# 4  2023-01-01 18:00     1  127.210265  37.732883  야  일    경기     차량단독
#
#   사고유형_중분류   사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별   발생시간
# 0       기타     기타  안전운전 의무 불이행      단일로  기타단일로      건설기계       보행자  07:00
# ...

# %%
df2.drop('발생년월일시',axis = 1)
# Out:
#       사망자수          경도         위도 주야 요일 발생지시도 사고유형_대분류 사고유형_중분류   사고유형  \
# 0        1  127.678579  36.967573  주  일    충북     차대사람       기타     기타
# 1        1  128.484013  34.853623  주  일    경남     차량단독       기타     기타
# 2        1  129.514309  36.042531  주  일    경북     차대사람       기타     기타
# 3        1  126.868199  37.239046  주  일    경기     차량단독    공작물충돌  공작물충돌
# 4        1  127.210265  37.732883  야  일    경기     차량단독       기타     기타
# ...    ...         ...        ... .. ..   ...      ...      ...    ...
# 2463     1  126.719489  37.702733  야  일    경기     차량단독    공작물충돌  공작물충돌
# 2464     1  128.592780  38.185021  주  일    강원      차대차       기타     기타
# 2465     1  128.180706  35.906771  주  일    경북     차량단독       기타     기타
# 2466     1  127.168430  36.828348  야  일    충남     차대사람      횡단중    횡단중
# 2467     1  129.414947  36.600059  야  일    경북      차대차     측면충돌   측면충돌
#
#           가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별   발생시간
# ...

# %%
df2.drop('발생년월일시',axis = 1 , inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1524\2456387960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('발생년월일시',axis = 1 , inplace = True)

# %% [markdown]
# ### 3.2 데이터 기초정보 정보 확인

# %% [markdown]
# * 최대값, 최소값, 평균값, 표준편차, 최빈값, 유일값, 결측치, 이상치 등의 정보를 재확인해 보세요

# %%
df2.describe()
# Out:
#               사망자수           경도           위도
# count  2468.000000  2468.000000  2468.000000
# mean      1.033630   127.580210    36.353688
# std       0.224384     0.860795     1.058923
# min       1.000000   124.663639    33.226256
# 25%       1.000000   126.911597    35.454856
# 50%       1.000000   127.283888    36.421606
# 75%       1.000000   128.342572    37.351820
# max       5.000000   130.909283    38.233345

# %%
df2.describe(include='object')
# Out:
#           주야    요일 발생지시도 사고유형_대분류 사고유형_중분류  사고유형      가해자법규위반 도로형태_대분류   도로형태  \
# count   2468  2468  2468     2468     2468  2468         2468     2468   2468
# unique     2     7    17        4       15    16            7        5     11
# top        주     금    경기      차대차       기타    기타  안전운전 의무 불이행      단일로  기타단일로
# freq    1359   387   489      997      605   605         1713     1482   1340
#
#        가해자_당사자종별 피해자_당사자종별   발생시간
# count       2468      2468   2468
# unique        12        14     24
# top          승용차       보행자  18:00
# freq        1141       849    134

# %% [markdown]
# ### 3.3 시각화를 통한 데이터이해 심화

# %% [markdown]
# * 데이터의 성격에 따라 이해도를 올리기 위해 시각화가 필요한 데이터차트를 만들어 보세요.
#   (Seaborn 추천: 페어플롯, 막대차트, 파이차트, 라인차트, 히스토그램등..)
# * 시각화한 차트에 대한 분석

# %%
value_counts = df2['주야'].value_counts().sort_index()

D_or_N = value_counts.index.tolist()
values = value_counts.values

# %%
values
# Out:
# array([1109, 1359], dtype=int64)

# %%
plt.pie(values, labels=D_or_N,autopct='%.2f%%')
plt.show()

# %%
value_counts = df2['요일'].value_counts().sort_index()

days = value_counts.index.tolist()
values = value_counts.values

# %%
values
# Out:
# array([387, 382, 374, 361, 297, 322, 345], dtype=int64)

# %%
plt.pie(values, labels=days,autopct='%.2f%%')
plt.show()

# %%
value_counts = df2['발생시간'].value_counts().sort_index()

times = value_counts.index.tolist()
values = value_counts.values

# %%
values
# Out:
# array([ 93,  71,  63,  58,  69, 116, 108,  97, 110, 122, 123, 125,  90,
#        119, 129, 116, 109, 111, 134, 118, 116,  85,  84, 102], dtype=int64)

# %%
plt.pie(values, labels=times,autopct='%.2f%%')
plt.show()

# %%
value_counts = df2['도로형태_대분류'].value_counts().sort_index()

road = value_counts.index.tolist()
values = value_counts.values

# %%
values
# Out:
# array([ 834,  150, 1482,    1,    1], dtype=int64)

# %%
plt.pie(values, labels=road,autopct='%.2f%%')
plt.show()

# %%
value_counts = df2['가해자_당사자종별'].value_counts().sort_index()

cars = value_counts.index.tolist()
values = value_counts.values

# %%
values
# Out:
# array([  24,   58,    1,   47,   28, 1141,  130,   36,  321,   64,   31,
#         587], dtype=int64)

# %%
plt.pie(values, labels=cars,autopct='%.2f%%')
plt.show()

# %%
m = folium.Map(location=[35.81, 128.85],
               zoom_start=7, 
               width=800, 
               height=550
              )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium import Marker
# for number, lat, lng, car in zip(df2['사망자수'],df2['위도'],df2['경도'],df2['가해자_당사자종별']):
#     Marker(location =[lat,lng],
#            popup=number,
#            tooltip=car,
#            icon=folium.Icon(color='blue',icon='bookmark')
#            ).add_to(m)

# %%
coords = df2[['위도','경도']]
marker_cluster = MarkerCluster().add_to(m)

# %%
for lat, long in zip(coords['위도'], coords['경도']):
    folium.Marker([lat, long], icon = folium.Icon(color="green")).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data= df3.sort_values(by='발생지시도'), x= "발생지시도" ,y= "등록차량대수")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df2.sort_values(by='발생지시도'), x="발생지시도",hue='가해자_당사자종별')
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='발생지시도', ylabel='Count'>

# %%
map_counts = df2['발생지시도'].value_counts()
map_counts
# Out:
# 발생지시도
# 경기    489
# 경북    254
# 경남    234
# 전남    221
# 충남    189
# 서울    177
# 전북    167
# 충북    150
# 강원    129
# 부산    100
# 인천     81
# 대구     80
# 대전     58
# 제주     43
# 광주     43
# 울산     40
# 세종     13
# Name: count, dtype: int64

# %%
map_count = pd.DataFrame(map_counts)

# %%
df_occurrences = {
    '발생지시도': ['경기', '경북', '경남', '전남', '충남', '서울', '전북', '충북', '강원', '부산', '인천', '대구', '대전', '제주', '광주', '울산', '세종'],
    '발생건수': [489, 254, 234, 221, 189, 177, 167, 150, 129, 100, 81, 80, 58, 43, 43, 40, 13]
}

df_occurrences = pd.DataFrame(df_occurrences)

# 발생건수를 등록차량대수로 나누어 새로운 열 추가
df_combined2 = df_occurrences.copy()  # 발생건수 데이터프레임 복사
df_combined2['발생비율'] = df_occurrences['발생건수']/ df_cars['등록차량대수']

df_combined2
# Out:
#    발생지시도  발생건수      발생비율
# 0     경기   489  0.000153
# 1     경북   254  0.000165
# 2     경남   234  0.000186
# 3     전남   221  0.000127
# 4     충남   189  0.000260
# 5     서울   177  0.000242
# 6     전북   167  0.000277
# 7     충북   150  0.000749
# 8     강원   129  0.000020
# 9     부산   100  0.000106
# 10    인천    81  0.000064
# 11    대구    80  0.000063
# 12    대전    58  0.000038
# 13    제주    43  0.000022
# 14    광주    43  0.000061
# 15    울산    40  0.000046
# 16    세종    13  0.000013

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data= df_combined2.sort_values(by='발생지시도'), x= "발생지시도" ,y= "발생비율")
plt.show()

# %%
# 운송 물량의 특성: 전라남도는 농산물 운송과 관련된 화물차량의 이동이 많을 수 있습니다. 
# 농축산물의 수확 시기나 특정 지역의 생산량에 따라 운송 물량이 증가하면서 사고 발생 가능성도 증가할 수 있습니다.

# %%
df3 = df2.sort_values(by='발생시간')

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df3, x="발생시간")
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='발생시간', ylabel='Count'>

# %% [markdown]
# # 4. 탐색적연구

# %% [markdown]
# #### Step1] 가설: 데이터 분석을 위한 목적, 대상 또는 가설을 세워본다.

# %% [markdown]
# * 사망 교통사고의 경우 해가 떠있는 낮시간 보다는 저녁에 많이 발생할것이다.
# * 비교적 차량이 더많을 주말에 교통사고량도 늘어날것이다.
# * 시간대별로는 차량이 많은 출퇴근시간에 좀더 많을것이다.
# * 단일로 보다는 교차로쪽에 사고가 많이 발생할것이다.
# * 사망 사고이다 보니 가해자 차량종은 일반 승용차 보다는 특수차량들이 많을것으로 예상된다.
# * 차량이 더많은 도시 지역에 사고가 많을것으로 예상된다.

# %% [markdown]
# #### Step2] 가설증명: 데이터 재 구조화, 시각화를 통해 새로운 insight 및 정보를 습득 및 가설을 검증한다.
# * 예) 나이별 월급에 대한 평균값을 구하고 line차트로 시각화하여 추세를 파악하여 가설을 검증한다.

# %% [markdown]
# #### Step3] 가설결론: 해당 가설에 대한 결론을 내린다.

# %% [markdown]
# * 사망 교통사고의 경우 저녁시간보다 오히려 낮에 더많이 발생한다.
# * 주말에는 오히려 발생빈도가 줄어든다.
# * 시간대 별로는 점심시간과 차량이 비교적적은 새벽시간에 줄어들고 나머지 시간에는 빈도수에 큰 차이가 없다.
# * 교차로 보다 단일로에서 교통사고가 더 많이 발생한다.
# * 승용차와 기타 특수차량의 사고빈도수의 합은 비슷하다.
# * 확실히 서울시와 기타광역시권에서 사고빈도가 높다.

# %% [markdown]
# #### Step4] 탐색적연구 반복: 시간 일정이 허락하는 범위내에서 Step1~Step3를 반복한다.

# %% [markdown]
# #### Step5] 최종결론: 지금까지 진행했던 모든 탐색적연구의 결과를 반영하여 최종 결론을 내린다.
